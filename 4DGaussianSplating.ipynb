# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/NeRFML/blob/main/4DGaussianSplating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hustvl/4DGaussians
# %cd 4DGaussians
# !git submodule update --init --recursive

# %%
# requirements.txt
"""
mmcv==1.6.0
matplotlib
argparse
lpips
plyfile
pytorch_msssim
open3d
"""

# %%
# %cd /content/4DGaussians
# !pip install -r requirements.txt
# !pip install -e submodules/depth-diff-gaussian-rasterization
# !pip install -e submodules/simple-knn

# %%
# %cd /content/4DGaussians
# !wget https://huggingface.co/camenduru/4DGaussians/resolve/main/data/data.zip
# !unzip data.zip

# %%
# Training
# %cd /content/4DGaussians
# !python train.py -s data/lego --port 6017 --expname "dnerf/lego" --configs arguments/dnerf/lego.py

# %%
# Rendering
# %cd /content/4DGaussians
# !python render.py --model_path "output/dnerf/lego/"  --skip_train --configs arguments/dnerf/lego.py

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open('/content/4DGaussians/output/dnerf/lego/video/ours_20000/video_rgb.mp4', 'rb').read()
data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
HTML(f"""
<video width="100%" height="100%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="100%" height="100%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# Custom Data
